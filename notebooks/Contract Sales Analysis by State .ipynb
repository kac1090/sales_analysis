# %%
import sys 

sys.path.insert(1, '../src')
import katie_work

# %%
df_contracts, df_customers = katie_work.load_data()

df_contracts.head()
# Out:
#    contract_id  customer_id contract_start  contract_term      deposit  \
# 0            1          127        8/17/19             12  $53,000.00
# 1            2          119        12/1/19             22  $77,000.00
# 2            3          160         5/1/19             15  $13,000.00
# 3            4            7        12/8/19             23  $56,000.00
# 4            5          144        2/11/19              7  $21,000.00
#
#    monthly_amt
# 0  $11,600.00
# 1  $14,600.00
# 2  $22,800.00
# 3  $11,400.00
# 4  $19,800.00

# %%
df_customers.head()
# Out:
#    id       company         sector                                 industry  \
# 0   1     Bubblebox  Capital Goods            Military/Government/Technical
# 1   2          Izio         Energy                     Oil & Gas Production
# 2   3  Twitterworks            NaN                                      NaN
# 3   4          Viva    Health Care                    Major Pharmaceuticals
# 4   5   Jabberstorm     Technology  Computer Software: Prepackaged Software
#
#                       email                     address         city state  \
# 0  kyerson0@bizjournals.com             76 Randy Circle    San Diego    CA
# 1       farlet1@comcast.net  15360 Village Green Street      Spokane    WA
# 2        alerohan2@ox.ac.uk               29 Hovde Hill    Milwaukee    WI
# 3  wgiovanitti3@nytimes.com            074 Center Place       Topeka    KS
# 4         pscallon4@fc2.com                 4 Moose Way  Terre Haute    IN
#
#      zip
# 0  92170
# 1  99252
# 2  53234
# 3  66667
# ...

# %%
df = katie_work.combine_data(df_contracts, df_customers)
df.head()
# Out:
#              contract_id contract_start  contract_term      deposit  \
# customer_id
# 1                     41        5/31/19             24  $86,000.00
# 1                    358        6/18/19             13  $74,000.00
# 1                    400        8/11/19             19  $38,000.00
# 1                    424        3/13/19             15  $77,000.00
# 1                    438       10/16/19             22  $39,000.00
#
#              monthly_amt    company         sector  \
# customer_id
# 1            $11,200.00   Bubblebox  Capital Goods
# 1            $19,000.00   Bubblebox  Capital Goods
# 1             $8,800.00   Bubblebox  Capital Goods
# 1            $14,300.00   Bubblebox  Capital Goods
# 1            $20,000.00   Bubblebox  Capital Goods
#
#                                   industry                     email  \
# customer_id
# 1            Military/Government/Technical  kyerson0@bizjournals.com
# ...

# %%
import pandas as pd

Data = {'deposit': ['86000','74000','38000','77000','39000'],
        'month_amt': ['11,200','19,000','8800','14300','20000']}
  
df = pd.DataFrame(Data)
  
df['deposit'] = df['deposit'].astype(int)
    
print(df)
# Out:
#    deposit month_amt
# 0    86000    11,200
# 1    74000    19,000
# 2    38000      8800
# 3    77000     14300
# 4    39000     20000

# %%
import pandas as pd
  
# Creating the dataframe 
df_contracts = pd.read_csv('../data/contracts.csv')
  
# Print the dataframe
df
# Out:
#    deposit month_amt
# 0    86000    11,200
# 1    74000    19,000
# 2    38000      8800
# 3    77000     14300
# 4    39000     20000

# %%
# applying groupby() function to
# group the data on team value.
gkk = df.groupby(['deposit','month_amt'])

  
# Let's print the first entries
# in all the groups formed.
gkk.first()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(38000, 8800), (39000, 20000), (74000, 19,000), (77000, 14300), (86000, 11,200)]
